# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import numpy as np
import warnings
#import goproject.data
warnings.filterwarnings('ignore')

# %% [markdown]
# # algunas predefinciones

# %%
def plot_barrios(barrios_elegidos):
    bsas_map = gpd.read_file('../../gopa_data/barrios-ciudad')
    puntos = gpd.GeoDataFrame(ciudad,
                             geometry = gpd.points_from_xy(ciudad.search_longitude, ciudad.search_latitude))

    fig,ax = plt.subplots(figsize = (10,10))
    bsas_map.plot(ax=ax, color='lightgrey')
    puntos[puntos['BARRIO'].isin(barrios_elegidos)].plot(ax=ax, markersize=5, color='red')
    ax.set_xlim([-58.550, -58.325])
    ax.set_ylim([-34.700, -34.525])
    plt.show()

# %% [markdown]
# #  cargamos dataset

# %%
ciudad = pd.read_csv('ciudad_barrios.csv')
ciudad.head(3)
# Out:
#    Unnamed: 0  search_longitude  search_latitude            timestamp  \
# 0           0        -58.441093       -34.587517  2021-03-06 03:40:51
# 1           1        -58.448010       -34.584375  2021-03-29 00:28:46
# 2           2        -58.451688       -34.585531  2021-03-16 23:17:52
#
#                  leave               arrive     search_method  \
# 0  2021-03-10 23:38:00  2021-03-10 10:38:00  searchInThisArea
# 1  2021-03-29 01:27:53  2021-03-29 00:27:53            google
# 2  2021-03-17 00:16:20  2021-03-16 23:16:20  searchInThisArea
#
#                             uid  \
# 0  IdVRqzjM1OQGXufqTmZIRv2CPhk1
# 1                           NaN
# 2                           NaN
#
#                                         geometry     BARRIO
# 0  POINT (-58.44109285622836 -34.58751745907739)  CHACARITA
# 1  POINT (-58.44800979999999 -34.58437500000001)  CHACARITA
# 2  POINT (-58.45168825238943 -34.58553119941662)  CHACARITA

# %%
ciudad['timestamp'] = pd.to_datetime(ciudad['timestamp'])
ciudad['arrive'] = pd.to_datetime(ciudad['arrive'])
ciudad['leave'] = pd.to_datetime(ciudad['leave'])
ciudad['hour'] = ciudad['arrive'].dt.hour
ciudad['month_number'] = ciudad.arrive.dt.month
ciudad['month_name'] = ciudad.arrive.dt.month_name()
ciudad['weekday'] = ciudad.arrive.dt.weekday
ciudad['weekday_name'] = ciudad.arrive.dt.day_name()

# %% [markdown]
# # elijamos un barrio

# %%
barrio_elegido = ['PALERMO']
#barrio_elegido = ['PALERMO','BELGRANO'] #también podemos leegir una lista de barrios!

# %%
barrio = ciudad[ciudad['BARRIO'].isin(barrio_elegido)]
#reemplazo los días de la semana en inglés
barrio.weekday_name = barrio.weekday_name.map({'Monday': 'lunes', 'Tuesday': 'martes', 'Wednesday': 'miercoles',
 'Thursday': 'jueves', 'Saturday': 'viernes', 'Friday': 'sabado', 'Sunday': 'domingo'})

# %%
plot_barrios(barrio_elegido)

# %% [markdown]
# # Analizamos por día

# %%
barrio.head(2)
# Out:
#       Unnamed: 0  search_longitude  search_latitude           timestamp  \
# 5499        5499        -58.418288       -34.581668 2021-02-13 15:13:03
# 5500        5500        -58.428174       -34.581082 2021-01-02 14:00:04
#
#                    leave              arrive     search_method  \
# 5499 2021-02-13 16:12:45 2021-02-13 15:12:45  searchInThisArea
# 5500 2021-01-02 15:00:55 2021-01-02 14:00:55         this_area
#
#                                uid  \
# 5499  e8itgepSU1YX6Q48HtrDpz76OXr1
# 5500               unauthenticated
#
#                                            geometry   BARRIO  hour  \
# 5499  POINT (-58.41828804463148 -34.58166840120946)  PALERMO    15
# 5500  POINT (-58.42817399650811 -34.58108154049506)  PALERMO    14
#
#       month_number month_name  weekday weekday_name
# 5499             2   February        5      viernes
# 5500             1    January        5      viernes

# %%
def distribucion_por_dia(df, dia= None):    
    if dia == None:
        return df.hour.value_counts(normalize=True).sort_index()
    
    elif dia.lower() in df.weekday_name.unique():
        cond = df['weekday_name'] == dia
        return df[cond].hour.value_counts(normalize=True).sort_index()
    
    else:
        print('error, día no encontrado')

def agregador(columna, n): #columna a dividir, número de partición
    columna = columna.sort_index()
    valores = [ ( f'{i}-{i+n}' , sum(columna[i:i+n]) ) for i in range(0,24,n) ]
    return pd.DataFrame(valores,columns=['horario','probabilidad']).set_index('horario')

def plotear_dia(df, dia, n):
    data = distribucion_por_dia(df, dia)
    agregado = agregador(data,n) 
    x = agregado.index
    y = agregado.probabilidad
    plt.figure(figsize=(15,6))
    plt.bar(x ,y*100, color = 'lightgreen')
    plt.grid(lw=0.4)
    plt.ylabel('probabilidad', fontdict = {'size':20})
    plt.xlabel('Franja Horaria', fontdict = {'size':20})
    
    if n == 1:
        plt.title(f'Distribución de probabilidad cada 1 hora el día {dia.upper()}:\n{barrio_elegido[0]}', fontdict = {'size':25})
    else:
        plt.title(f'Distribución de probabilidad cada {n} horas el día {dia.upper()}:\n{barrio_elegido[0]}', fontdict = {'size':25})

    
    font = {'family': 'monospace' ,  'color':  'white',
            'size': 10, 'horizontalalignment':'center'}
    for i in range(24//n):
        plt.text(i, #x
                 y[i]*50,
                 f'{round(y[i]*100, 2)}%', 
                 fontdict=font,
                 path_effects=[pe.withStroke(linewidth=2, foreground="black")])

    plt.show()

# %% [markdown]
# -----
# hora a hora

# %%
dias = ['lunes', 'martes', 'miercoles', 'jueves', 'viernes', 'sabado', 'domingo']

for dia_semana in dias :
    plotear_dia(barrio, dia_semana ,2)

# %% [markdown]
# ## pedir toda la data en un dataframe

# %%
def frecuencias_df(df=None,n_agregacion=1,con_semana=False): #dataframe, número de agregación horaria, agregarle columna con total semanal o no

    dias_semana = ['lunes', 'martes', 'miercoles', 'jueves', 'viernes', 'sabado', 'domingo']

    if n_agregacion == 1:
        data = pd.DataFrame()
        for i in dias_semana[0:]:
            data[i] = distribucion_por_dia(df, i)
            data[i].replace(np.nan, 0, inplace=True)
        #data.columns = dias_semana
        if con_semana == True:
            data['semana'] = distribucion_por_dia(df)
    
    else:
        dias = ['lunes', 'martes', 'miercoles', 'jueves', 'viernes', 'sabado', 'domingo']
        data = pd.DataFrame(agregador(distribucion_por_dia(df, dias[0]) , n_agregacion))
        for i in dias_semana[1:]:
            data[i] = agregador(distribucion_por_dia(df, i) , n_agregacion)
        data.columns = dias
        if con_semana == True:
            data['semana'] = agregador(distribucion_por_dia(df) , n_agregacion)
        
    return data

# %% [markdown]
# ### formateo del dataframe

# %%
distribucion = frecuencias_df(barrio, 1, con_semana=True)
np.sum(distribucion, axis = 0)
# Out:
# lunes        1.000000
# martes       0.996063
# miercoles    0.955326
# jueves       0.960289
# viernes      0.976636
# sabado       0.989899
# domingo      0.961538
# semana       0.976518
# dtype: float64

# %% [markdown]
# #  REVISAR PORQUE LOS NÚMEROS NO DAN!

# %%
def bar_formatter(df):
    return df.style.format(formatter='{:.3f}%').bar(color = 'lightgreen', vmax=distribucion.semana.max()*1.5,
                                                                  vmin = 0, 
                                                                  align = 'left',
                                                                  subset = 'semana')\
    .background_gradient(cmap = 'BuPu', subset = df.columns[0:-1],
                        low = 0, high = 4) 
    
bar_formatter(distribucion)
# Out:
# <style  type="text/css" >
# #T_9a3c7_row0_col0,#T_9a3c7_row7_col2,#T_9a3c7_row9_col2,#T_9a3c7_row11_col5,#T_9a3c7_row12_col5,#T_9a3c7_row15_col6,#T_9a3c7_row19_col2,#T_9a3c7_row22_col6{
#             background-color:  #f0f7fa;
#             color:  #000000;
#         }#T_9a3c7_row0_col1,#T_9a3c7_row4_col4,#T_9a3c7_row9_col6,#T_9a3c7_row19_col6{
#             background-color:  #e7f1f7;
#             color:  #000000;
#         }#T_9a3c7_row0_col2,#T_9a3c7_row1_col1,#T_9a3c7_row2_col0,#T_9a3c7_row2_col3,#T_9a3c7_row2_col5,#T_9a3c7_row3_col2,#T_9a3c7_row3_col3,#T_9a3c7_row3_col4,#T_9a3c7_row3_col5,#T_9a3c7_row5_col6{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_9a3c7_row0_col3,#T_9a3c7_row1_col5,#T_9a3c7_row2_col4,#T_9a3c7_row5_col1,#T_9a3c7_row5_col2,#T_9a3c7_row6_col4,#T_9a3c7_row7_col1,#T_9a3c7_row8_col1,#T_9a3c7_row10_col5{
#             background-color:  #eff6fa;
#             color:  #000000;
#         }#T_9a3c7_row0_col4,#T_9a3c7_row1_col2,#T_9a3c7_row11_col1,#T_9a3c7_row12_col2,#T_9a3c7_row15_col1{
#             background-color:  #e6f0f6;
#             color:  #000000;
#         }#T_9a3c7_row0_col5,#T_9a3c7_row15_col2{
#             background-color:  #e8f1f7;
#             color:  #000000;
#         }#T_9a3c7_row0_col6,#T_9a3c7_row3_col6,#T_9a3c7_row12_col0,#T_9a3c7_row17_col0{
#             background-color:  #eef6fa;
#             color:  #000000;
#         }#T_9a3c7_row0_col7,#T_9a3c7_row7_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 25.6%, transparent 25.6%);
#         }#T_9a3c7_row1_col0,#T_9a3c7_row12_col4,#T_9a3c7_row22_col3{
#             background-color:  #ddeaf3;
#             color:  #000000;
#         }#T_9a3c7_row1_col3,#T_9a3c7_row1_col6,#T_9a3c7_row2_col6,#T_9a3c7_row6_col3,#T_9a3c7_row7_col5,#T_9a3c7_row19_col4,#T_9a3c7_row21_col2,#T_9a3c7_row21_col4,#T_9a3c7_row21_col5{
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }#T_9a3c7_row1_col4,#T_9a3c7_row6_col5,#T_9a3c7_row20_col0,#T_9a3c7_row22_col2{
#             background-color:  #ebf3f8;
#             color:  #000000;
#         }#T_9a3c7_row1_col7,#T_9a3c7_row22_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 26.5%, transparent 26.5%);
#         }#T_9a3c7_row2_col1,#T_9a3c7_row6_col1,#T_9a3c7_row10_col1,#T_9a3c7_row20_col5{
#             background-color:  #f2f8fb;
#             color:  #000000;
#         }#T_9a3c7_row2_col2{
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }#T_9a3c7_row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.8%, transparent 7.8%);
#         }#T_9a3c7_row3_col0,#T_9a3c7_row4_col0,#T_9a3c7_row6_col6,#T_9a3c7_row8_col0{
#             background-color:  #f6fbfc;
#             color:  #000000;
#         }#T_9a3c7_row3_col1,#T_9a3c7_row4_col1,#T_9a3c7_row20_col1,#T_9a3c7_row21_col0,#T_9a3c7_row22_col0{
#             background-color:  #f3f9fc;
#             color:  #000000;
#         }#T_9a3c7_row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 5.9%, transparent 5.9%);
#         }#T_9a3c7_row4_col2{
#             background-color:  #ebf4f8;
#             color:  #000000;
#         }#T_9a3c7_row4_col3,#T_9a3c7_row5_col0,#T_9a3c7_row10_col0,#T_9a3c7_row11_col6,#T_9a3c7_row12_col6,#T_9a3c7_row13_col1,#T_9a3c7_row14_col0,#T_9a3c7_row16_col4,#T_9a3c7_row18_col5,#T_9a3c7_row22_col4{
#             background-color:  #e9f2f7;
#             color:  #000000;
#         }#T_9a3c7_row4_col5,#T_9a3c7_row5_col4,#T_9a3c7_row5_col5,#T_9a3c7_row6_col2,#T_9a3c7_row7_col6,#T_9a3c7_row8_col2,#T_9a3c7_row14_col6,#T_9a3c7_row22_col5{
#             background-color:  #f4fafc;
#             color:  #000000;
#         }#T_9a3c7_row4_col6,#T_9a3c7_row11_col4{
#             background-color:  #f3f9fb;
#             color:  #000000;
#         }#T_9a3c7_row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 19.6%, transparent 19.6%);
#         }#T_9a3c7_row5_col3{
#             background-color:  #d6e4f0;
#             color:  #000000;
#         }#T_9a3c7_row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 22.4%, transparent 22.4%);
#         }#T_9a3c7_row6_col0,#T_9a3c7_row7_col4,#T_9a3c7_row8_col4,#T_9a3c7_row10_col4,#T_9a3c7_row22_col1{
#             background-color:  #ecf4f9;
#             color:  #000000;
#         }#T_9a3c7_row6_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 17.4%, transparent 17.4%);
#         }#T_9a3c7_row7_col0,#T_9a3c7_row9_col0,#T_9a3c7_row9_col3,#T_9a3c7_row10_col6,#T_9a3c7_row14_col4,#T_9a3c7_row20_col6{
#             background-color:  #e3eef5;
#             color:  #000000;
#         }#T_9a3c7_row7_col3,#T_9a3c7_row10_col3,#T_9a3c7_row21_col3{
#             background-color:  #e1ecf4;
#             color:  #000000;
#         }#T_9a3c7_row8_col3,#T_9a3c7_row9_col4,#T_9a3c7_row13_col3,#T_9a3c7_row15_col4,#T_9a3c7_row18_col3,#T_9a3c7_row19_col0{
#             background-color:  #dfebf4;
#             color:  #000000;
#         }#T_9a3c7_row8_col5,#T_9a3c7_row10_col2,#T_9a3c7_row15_col0,#T_9a3c7_row17_col6,#T_9a3c7_row18_col0,#T_9a3c7_row19_col1,#T_9a3c7_row20_col2{
#             background-color:  #e1edf5;
#             color:  #000000;
#         }#T_9a3c7_row8_col6,#T_9a3c7_row9_col1,#T_9a3c7_row13_col6{
#             background-color:  #eaf3f8;
#             color:  #000000;
#         }#T_9a3c7_row8_col7,#T_9a3c7_row20_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 29.7%, transparent 29.7%);
#         }#T_9a3c7_row9_col5,#T_9a3c7_row14_col1,#T_9a3c7_row17_col1,#T_9a3c7_row17_col3,#T_9a3c7_row20_col3,#T_9a3c7_row20_col4{
#             background-color:  #eef5f9;
#             color:  #000000;
#         }#T_9a3c7_row9_col7,#T_9a3c7_row10_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 36.1%, transparent 36.1%);
#         }#T_9a3c7_row11_col0,#T_9a3c7_row17_col4{
#             background-color:  #d8e6f0;
#             color:  #000000;
#         }#T_9a3c7_row11_col2,#T_9a3c7_row11_col3,#T_9a3c7_row12_col3,#T_9a3c7_row13_col2,#T_9a3c7_row13_col4,#T_9a3c7_row14_col3,#T_9a3c7_row18_col2,#T_9a3c7_row18_col6{
#             background-color:  #e4eff6;
#             color:  #000000;
#         }#T_9a3c7_row11_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 37.4%, transparent 37.4%);
#         }#T_9a3c7_row12_col1,#T_9a3c7_row16_col0,#T_9a3c7_row16_col3,#T_9a3c7_row16_col6,#T_9a3c7_row17_col2,#T_9a3c7_row17_col5,#T_9a3c7_row18_col4{
#             background-color:  #ccddec;
#             color:  #000000;
#         }#T_9a3c7_row12_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 44.3%, transparent 44.3%);
#         }#T_9a3c7_row13_col0{
#             background-color:  #dae7f1;
#             color:  #000000;
#         }#T_9a3c7_row13_col5,#T_9a3c7_row21_col6{
#             background-color:  #d4e3ef;
#             color:  #000000;
#         }#T_9a3c7_row13_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 51.6%, transparent 51.6%);
#         }#T_9a3c7_row14_col2{
#             background-color:  #e2edf5;
#             color:  #000000;
#         }#T_9a3c7_row14_col5,#T_9a3c7_row18_col1{
#             background-color:  #e0ecf4;
#             color:  #000000;
#         }#T_9a3c7_row14_col7,#T_9a3c7_row19_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 39.7%, transparent 39.7%);
#         }#T_9a3c7_row15_col3{
#             background-color:  #d1e1ee;
#             color:  #000000;
#         }#T_9a3c7

# %% [markdown]
# # Ahora, a repetir todo para la hora de llegada estimada!
